# %%
import pandas as pd

# %%
df = pd.read_parquet("./data/mta_transfer.parquet")
df.head()
# Out:
#                                                                              address  \
# block_number transaction_index log_index
# 10450640     159               153        0xa3bed4e1c75d00fa6f4e5e6922db7261b5e9acd2
# 10450649     222               173        0xa3bed4e1c75d00fa6f4e5e6922db7261b5e9acd2
#                                176        0xa3bed4e1c75d00fa6f4e5e6922db7261b5e9acd2
# 10476280     131               164        0xa3bed4e1c75d00fa6f4e5e6922db7261b5e9acd2
# 10476285     187               123        0xa3bed4e1c75d00fa6f4e5e6922db7261b5e9acd2
#
#                                                                                  block_hash  \
# block_number transaction_index log_index
# 10450640     159               153        0x3e8959e9f1b28b7a7e597379bdefa00f8be1f62f2125...
# 10450649     222               173        0x7b462b18f27f23c3c44af55f88b04eb5bb1f6dd6da25...
#                                176        0x7b462b18f27f23c3c44af55f88b04eb5bb1f6dd6da25...
# ...

# %%
df = pd.read_parquet("./data/stkmta_staked.parquet")
df.head()
# Out:
#                                                                              address  \
# block_number transaction_index log_index
# 13236086     141               271        0x8f2326316ec696f6d023e37a9931c2b2c177a3d7
# 13236789     29                73         0x8f2326316ec696f6d023e37a9931c2b2c177a3d7
# 13238034     125               181        0x8f2326316ec696f6d023e37a9931c2b2c177a3d7
# 13238215     28                69         0x8f2326316ec696f6d023e37a9931c2b2c177a3d7
# 13239687     243               431        0x8f2326316ec696f6d023e37a9931c2b2c177a3d7
#
#                                                                                  block_hash  \
# block_number transaction_index log_index
# 13236086     141               271        0xa84ab77ec59b5b46dbaff258e3ad01c3fcb60a4232be...
# 13236789     29                73         0x33862e3beadce5ba537deb85a74827127203ce845405...
# 13238034     125               181        0x960b9c7a4789b435312299a61f031e8fe3c8cb57ad6a...
# ...
